# %%
import numpy as np
from lib.julia import Julia
from lib.mandelbrot import Mandelbrot
from lib.vizualizace import Fraktal

# %% [markdown]
# ### Mandelbrotova množina

# %%
mandelbrot = Mandelbrot(
    x_min=-2.0, x_max=1.0,
    y_min=-1.5, y_max=1.5,
    width=800, height=800,
    max_iter=100
)
Fraktal(mandelbrot)

# %% [markdown]
# ### Juliova množina

# %%
julia = Julia(
    width=800, height=800,
    x_min=-1.5, x_max=1.5,
    y_min=-1.5, y_max=1.5,
    max_iter=200,
    c=-0.8 + 0.156j
)
Fraktal(julia)
